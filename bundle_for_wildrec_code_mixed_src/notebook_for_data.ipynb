# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('./reference_data_1/gold_test.csv')
df2 = pd.read_csv('./reference_data_2/gold_test.csv')
df3 = pd.read_csv('./reference_data_3/gold_test.csv')
print(df1.shape, df2.shape, df3.shape)
# Out:
# (151, 3) (537, 3) (185, 3)

# %%
df3
# Out:
#          ids                                           sentence sentiment
# 0    mag_231                     Mar jaihe Jio tab khaiye gheev  negative
# 1    mag_090      Shuddh magadhi blog hako padh ke nitraiboo Na  negative
# 2    mag_115  हमनी के मगही और अपने के मैथिली दोनो बिहार के प...  positive
# 3    mag_160  Jiyo bhai jiyo Shahrukh was cool Haha I apprec...  positive
# 4    mag_075                            बात ते एकदम ठीके कहलहुँ  positive
# ..       ...                                                ...       ...
# 180  mag_122  शेयर करहु जेतना हो सके उतना शेयर करहु हल। ई वी...  positive
# 181  mag_056                       Pranam bhaiyaau SB thik hako  positive
# 182  mag_161  I have seen you in TVF/TSP  Badi badhiya  kata...  positive
# 183  mag_151  Aaj grahan lagtai ta sab kahe thai ki 12 ghant...       mix
# 184  mag_078  बहुत नेक काम कलहू डॉक्टर साहब से मिलाके , बहुत...  positive
#
# [185 rows x 3 columns]

# %%
df3['sentiment']='positive'

# %%
df3
# Out:
#          ids                                           sentence sentiment
# 0    mag_231                     Mar jaihe Jio tab khaiye gheev  positive
# 1    mag_090      Shuddh magadhi blog hako padh ke nitraiboo Na  positive
# 2    mag_115  हमनी के मगही और अपने के मैथिली दोनो बिहार के प...  positive
# 3    mag_160  Jiyo bhai jiyo Shahrukh was cool Haha I apprec...  positive
# 4    mag_075                            बात ते एकदम ठीके कहलहुँ  positive
# ..       ...                                                ...       ...
# 180  mag_122  शेयर करहु जेतना हो सके उतना शेयर करहु हल। ई वी...  positive
# 181  mag_056                       Pranam bhaiyaau SB thik hako  positive
# 182  mag_161  I have seen you in TVF/TSP  Badi badhiya  kata...  positive
# 183  mag_151  Aaj grahan lagtai ta sab kahe thai ki 12 ghant...  positive
# 184  mag_078  बहुत नेक काम कलहू डॉक्टर साहब से मिलाके , बहुत...  positive
#
# [185 rows x 3 columns]

# %%
df3.to_csv('./submission_samples/maghi_sample.csv', index=False)
